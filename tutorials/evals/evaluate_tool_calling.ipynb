# %% [markdown]
# <a href="https://colab.research.google.com/github/hdotking/RAG/blob/main/tutorials/evals/evaluate_tool_calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <p style="text-align:center">
#         <img alt="phoenix logo" src="https://storage.googleapis.com/arize-phoenix-assets/assets/phoenix-logo-light.svg" width="200"/>
#         <br>
#         <a href="https://docs.arize.com/phoenix/">Docs</a>
#         |
#         <a href="https://github.com/Arize-ai/phoenix">GitHub</a>
#         |
#         <a href="https://join.slack.com/t/arize-ai/shared_invite/zt-1px8dcmlf-fmThhDFD_V_48oU7ALan4Q">Community</a>
#     </p>
# </center>
# <h1 align="center">Tool Calling Evals</h1>
#
# The purpose of this notebook is:
#
# - to evaluate the multi-step LLM logic involved in tool calling,
# - to provide an experimental framework for users to iterate and improve on the default evaluation template.
#
# ## Install Dependencies and Import Libraries

# %%
# !pip install pip-tools
# Out:
# Collecting pip-tools
#   Downloading pip_tools-7.4.1-py3-none-any.whl.metadata (26 kB)
# Collecting build>=1.0.0 (from pip-tools)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.10/dist-packages (from pip-tools) (8.1.7)
# Requirement already satisfied: pip>=22.2 in /usr/local/lib/python3.10/dist-packages (from pip-tools) (24.1.2)
# Collecting pyproject-hooks (from pip-tools)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pip-tools) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from pip-tools) (0.45.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from pip-tools) (2.2.1)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.0->pip-tools) (24.2)
# Downloading pip_tools-7.4.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.7 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyproject-hooks, build, pip-tools
# Successfully installed build-1.2.2.post1 pip-tools-7.4.1 pyproject-hooks-1.2.0

# %%
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.5.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.5.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 72.5 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.5.7

# %%
# !uv pip compile requirements.in --output-file=requirements.txt
# Out:
# Resolved 153 packages in 2.75s
# # This file was autogenerated by uv via the following command:
# #    uv pip compile requirements.in --output-file=requirements.txt
# absl-py==1.4.0
#     # via
#     #   keras
#     #   tensorboard
#     #   tensorflow
#     #   tensorflow-metadata
# aiohappyeyeballs==2.4.4
#     # via aiohttp
# aiohttp==3.11.10
#     # via
#     #   gcsfs
#     #   langchain
#     #   llama-index-core
# aioitertools==0.12.0
#     # via arize-phoenix
# aiosignal==1.3.1
#     # via aiohttp
# aiosqlite==0.20.0
#     # via arize-phoenix
# alembic==1.14.0
#     # via arize-phoenix
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.7.0
#     # via
#     #   httpx
#     #   openai
#     #   starlette
# arize-phoenix==6.1.0
#     # via -r requirements.in
# arize-phoenix-evals==0.17.5
#     # via arize-phoenix
# arize-phoenix-otel==0.6.1
#     # via arize-phoenix
# astunparse==1.6.3
#     # via tensorflow
# async-timeout==4.0.3
#     # via
#     #   aiohttp
#     #   langchain
# attrs==24.2.0
#     # via aiohttp
# authlib==1.3.2
#     # via arize-phoenix
# cachetools==5.5.0
#     # via
#     #   arize-phoenix
#     #   google-auth
# certifi==2024.8.30
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
# cffi==1.17.1
#     # via cryptography
# charset-normalizer==3.4.0
#     # via requests
# click==8.1.7
#     # via
#     #   nltk
#     #   uvicorn
# cryptography==44.0.0
#     # via authlib
# dataclasses-json==0.6.7
#     # via llama-index-core
# decorator==5.1.1
#     # via gcsfs
# deprecated==1.2.15
#     # via
#     #   llama-index-core
#     #   opentelemetry-api
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
#     #   opentelemetry-semantic-conventions
# dirtyjson==1.0.8
#     # via llama-index-core
# distro==1.9.0
#     # via openai
# exceptiongroup==1.2.2
#     # via anyio
# fastapi==0.115.6
#     # via arize-phoenix
# filetype==1.2.0
#     # via llama-index-core
# flatbuffers==24.3.25
#     # via tensorflow
# frozenlist==1.5.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2024.10.0
#     # via
#     #   gcsfs
#     #   llama-index-core
# gast==0.6.0
#     # via tensorflow
# gcsfs==2024.10.0
#     # via -r requirements.in
# google-api-core==2.23.0
#     # via
#     #   google-cloud-core
#     #   google-cloud-storage
# google-auth==2.36.0
#     # via
#     #   gcsfs
#     #   google-api-core
#     #   google-auth-oauthlib
#     #   google-cloud-core
#     #   google-cloud-storage
# google-auth-oauthlib==1.2.1
#     # via gcsfs
# google-cloud-core==2.4.1
#     # via google-cloud-storage
# google-cloud-storage==2.19.0
#     # via gcsfs
# google-crc32c==1.6.0
#     # via
#     #   google-cloud-storage
#     #   google-resumable-media
# google-pasta==0.2.0
#     # via tensorflow
# google-resumable-media==2.7.2
#     # via google-cloud-storage
# googleapis-common-protos==1.66.0
#     # via
#     #   google-api-core
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
#     #   tensorflow-metadata
# graphql-core==3.2.5
#     # via strawberry-graphql
# greenlet==3.1.1
#     # via sqlalchemy
# grpc-interceptor==0.15.4
#     # via arize-phoenix
# grpcio==1.68.1
#     # via
#     #   arize-phoenix
#     #   grpc-interceptor
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   tensorboard
#     #   tensorflow
# h11==0.14.0
#     # via
#     #   httpcore
#     #   uvicorn
# h5py==3.12.1
#     # via
#     #   keras
#     #   tensorflow
# httpcore==1.0.7
#     # via httpx
# httpx==0.27.2
#     # via
#     #   -r requirements.in
#     #   arize-phoenix
#     #   langsmith
#     #   llama-index-core
#     #   openai
# idna==3.10
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# importlib-metadata==8.4.0
#     # via opentelemetry-api
# jinja2==3.1.4
#     # via arize-phoenix
# jiter==0.8.0
#     # via openai
# joblib==1.4.2
#     # via
#     #   nltk
#     #   scikit-learn
# jsonpatch==1.33
#     # via langchain-core
# jsonpointer==3.0.0
#     # via jsonpatch
# keras==3.7.0
#     # via tensorflow
# langchain==0.3.10
#     # via -r requirements.in
# langchain-core==0.3.22
#     # via
#     #   langchain
#     #   langchain-openai
#     #   langchain-text-splitters
# langchain-openai==0.2.11
#     # via -r requirements.in
# langchain-text-splitters==0.3.2
#     # via langchain
# langsmith==0.1.147
#     # via
#     #   langchain
#     #   langchain-core
# libclang==18.1.1
#     # via tensorflow
# llama-index-core==0.12.0
#     # via llama-index-llms-openai
# llama-index-llms-openai==0.3.2
#     # via -r requirements.in
# mako==1.3.8
#     # via alembic
# markdown==3.7
#     # via tensorboard
# markdown-it-py==3.0.0
#     # via rich
# markupsafe==3.0.2
#     # via
#     #   jinja2
#     #   mako
#     #   werkzeug
# marshmallow==3.23.1
#     # via dataclasses-json
# mdurl==0.1.2
#     # via markdown-it-py
# ml-dtypes==0.4.1
#     # via
#     #   keras
#     #   tensorflow
# multidict==6.1.0
#     # via
#     #   aiohttp
#     #   yarl
# mypy-extensions==1.0.0
#     # via typing-inspect
# namex==0.0.8
#     # via keras
# nest-asyncio==1.6.0
#     # via
#     #   -r requirements.in
#     #   llama-index-core
# networkx==3.4.2
#     # via llama-index-core
# nltk==3.9.1
#     # via llama-index-core
# numpy==1.26.4
#     # via
#     #   arize-phoenix
#     #   h5py
#     #   keras
#     #   langchain
#     #   llama-index-core
#     #   ml-dtypes
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   tensorboard
#     #   tensorflow
# oauthlib==3.2.2
#     # via requests-oauthlib
# openai==1.57.0
#     # via
#     #   -r requirements.in
#     #   langchain-openai
#     #   llama-index-llms-openai
# openinference-instrumentation==0.1.19
#     # via
#     #   arize-phoenix
#     #   openinference-instrumentation-langchain
# openinference-instrumentation-langchain==0.1.29
#     # via -r requirements.in
# openinference-semantic-conventions==0.1.12
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-otel
#     #   openinference-instrumentation
#     #   openinference-instrumentation-langchain
# opentelemetry-api==1.27.0
#     # via
#     #   openinference-instrumentation
#     #   openinference-instrumentation-langchain
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
#     #   opentelemetry-instrumentation
#     #   opentelemetry-sdk
#     #   opentelemetry-semantic-conventions
# opentelemetry-exporter-otlp==1.27.0
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-otel
# opentelemetry-exporter-otlp-proto-common==1.27.0
#     # via
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
# opentelemetry-exporter-otlp-proto-grpc==1.27.0
#     # via opentelemetry-exporter-otlp
# opentelemetry-exporter-otlp-proto-http==1.27.0
#     # via opentelemetry-exporter-otlp
# opentelemetry-instrumentation==0.48b0
#     # via openinference-instrumentation-langchain
# opentelemetry-proto==1.27.0
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-otel
#     #   opentelemetry-exporter-otlp-proto-common
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
# opentelemetry-sdk==1.27.0
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-otel
#     #   openinference-instrumentation
#     #   opentelemetry-exporter-otlp-proto-grpc
#     #   opentelemetry-exporter-otlp-proto-http
# opentelemetry-semantic-conventions==0.48b0
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-otel
#     #   openinference-instrumentation-langchain
#     #   opentelemetry-sdk
# opt-einsum==3.4.0
#     # via tensorflow
# optree==0.13.1
#     # via keras
# orjson==3.10.12
#     # via langsmith
# packaging==24.2
#     # via
#     #   keras
#     #   langchain-core
#     #   marshmallow
#     #   tensorboard
#     #   tensorflow
# pandas==2.2.3
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-evals
# pillow==11.0.0
#     # via llama-index-core
# propcache==0.2.1
#     # via
#     #   aiohttp
#     #   yarl
# proto-plus==1.25.0
#     # via google-api-core
# protobuf==4.25.5
#     # via
#     #   -r requirements.in
#     #   arize-phoenix
#     #   google-api-core
#     #   googleapis-common-protos
#     #   opentelemetry-proto
#     #   proto-plus
#     #   tensorboard
#     #   tensorflow
#     #   tensorflow-metadata
# psutil==6.1.0
#     # via arize-phoenix
# pyarrow==18.1.0
#     # via arize-phoenix
# pyasn1==0.6.1
#     # via
#     #   pyasn1-modules
#     #   rsa
# pyasn1-modules==0.4.1
#     # via google-auth
# pycparser==2.22
#     # via cffi
# pydantic==2.10.3
#     # via
#     #   arize-phoenix
#     #   fastapi
#     #   langchain
#     #   langchain-core
#     #   langsmith
#     #   llama-index-core
#     #   openai
# pydantic-core==2.27.1
#     # via pydantic
# pygments==2.18.0
#     # via rich
# python-dateutil==2.9.0.post0
#     # via
#     #   pandas
#     #   strawberry-graphql
# python-multipart==0.0.19
#     # via arize-phoenix
# pytz==2024.2
#     # via pandas
# pyyaml==6.0.2
#     # via
#     #   langchain
#     #   langchain-core
#     #   llama-index-core
# regex==2024.11.6
#     # via
#     #   nltk
#     #   tiktoken
# requests==2.32.3
#     # via
#     #   gcsfs
#     #   google-api-core
#     #   google-cloud-storage
#     #   langchain
#     #   langsmith
#     #   llama-index-core
#     #   opentelemetry-exporter-otlp-proto-http
#     #   requests-oauthlib
#     #   requests-toolbelt
#     #   tensorflow
#     #   tiktoken
# requests-oauthlib==2.0.0
#     # via google-auth-oauthlib
# requests-toolbelt==1.0.0
#     # via langsmith
# rich==13.9.4
#     # via keras
# rsa==4.9
#     # via google-auth
# scikit-learn==1.5.2
#     # via arize-phoenix
# scipy==1.14.1
#     # via
#     #   arize-phoenix
#     #   scikit-learn
# setuptools==75.6.0
#     # via
#     #   opentelemetry-instrumentation
#     #   tensorboard
#     #   tensorflow
# six==1.17.0
#     # via
#     #   astunparse
#     #   google-pasta
#     #   python-dateutil
#     #   tensorboard
#     #   tensorflow
# sniffio==1.3.1
#     # via
#     #   anyio
#     #   httpx
#     #   openai
# sqlalchemy==2.0.36
#     # via
#     #   alembic
#     #   arize-phoenix
#     #   langchain
#     #   llama-index-core
# sqlean-py==3.47.0
#     # via arize-phoenix
# starlette==0.41.3
#     # via
#     #   arize-phoenix
#     #   fastapi
# strawberry-graphql==0.243.1
#     # via arize-phoenix
# tenacity==8.5.0
#     # via
#     #   langchain
#     #   langchain-core
#     #   llama-index-core
# tensorboard==2.17.1
#     # via tensorflow
# tensorboard-data-server==0.7.2
#     # via tensorboard
# tensorflow==2.17.1
#     # via -r requirements.in
# tensorflow-io-gcs-filesystem==0.37.1
#     # via tensorflow
# tensorflow-metadata==1.13.1
#     # via -r requirements.in
# termcolor==2.5.0
#     # via tensorflow
# threadpoolctl==3.5.0
#     # via scikit-learn
# tiktoken==0.8.0
#     # via
#     #   langchain-openai
#     #   llama-index-core
# tqdm==4.67.1
#     # via
#     #   arize-phoenix
#     #   arize-phoenix-evals
#     #   llama-index-core
#     #   nltk
#     #   openai
# typing-extensions==4.12.2
#     # via
#     #   aiosqlite
#     #   alembic
#     #   anyio
#     #   arize-phoenix
#     #   arize-phoenix-evals
#     #   arize-phoenix-otel
#     #   fastapi
#     #   langchain-core
#     #   llama-index-core
#     #   multidict
#     #   openai
#     #   opentelemetry-sdk
#     #   optree
#     #   pydantic
#     #   pydantic-core
#     #   rich
#     #   sqlalchemy
#     #   strawberry-graphql
#     #   tensorflow
#     #   typing-inspect
#     #   uvicorn
# typing-inspect==0.9.0
#     # via
#     #   dataclasses-json
#     #   llama-index-core
# tzdata==2024.2
#     # via pandas
# urllib3==2.2.3
#     # via requests
# uvicorn==0.32.1
#     # via arize-phoenix
# websockets==14.1
#     # via arize-phoenix
# werkzeug==3.1.3
#     # via tensorboard
# wheel==0.45.1
#     # via astunparse
# wrapt==1.17.0
#     # via
#     #   arize-phoenix
#     #   deprecated
#     #   llama-index-core
#     #   openinference-instrumentation-langchain
#     #   opentelemetry-instrumentation
#     #   tensorflow
# yarl==1.18.3
#     # via aiohttp
# zipp==3.21.0
#     # via importlib-metadata

# %%
# !uv pip install --system -r requirements.txt
# Out:
# Using Python 3.10.12 environment at: /usr
# Resolved 153 packages in 217ms
# ⠙ Preparing packages... (0/34)
# ⠙ Preparing packages... (0/34)
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------     0 B/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------     0 B/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------     0 B/25.65 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------     0 B/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------     0 B/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------     0 B/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# tqdm       ------------------------------     0 B/76.70 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-api ------------------------------     0 B/62.47 KiB
# tqdm       ------------------------------     0 B/76.70 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/18.11 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-api ------------------------------     0 B/62.47 KiB
# tqdm       ------------------------------     0 B/76.70 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# ⠙ Preparing packages... (0/34)
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/18.11 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-api ------------------------------     0 B/62.47 KiB
# tqdm       ------------------------------     0 B/76.70 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# psutil     ------------------------------ 14.88 KiB/280.52 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp ------------------------------     0 B/6.84 KiB
# decorator  ------------------------------ 8.86 KiB/8.86 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/18.11 KiB
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------     0 B/28.76 KiB
# opentelemetry-proto ------------------------------     0 B/51.23 KiB
# opentelemetry-api ------------------------------     0 B/62.47 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# anyio      ------------------------------     0 B/90.87 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/146.18 KiB
# google-api-core ------------------------------     0 B/152.88 KiB
# google-auth ------------------------------     0 B/204.61 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp ------------------------------     0 B/6.84 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 14.85 KiB/16.80 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------     0 B/18.11 KiB
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------     0 B/28.76 KiB
# opentelemetry-proto ------------------------------     0 B/51.23 KiB
# opentelemetry-api ------------------------------     0 B/62.47 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# anyio      ------------------------------     0 B/90.87 KiB
# opentelemetry-sdk ------------------------------ 14.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 14.86 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/146.18 KiB
# google-api-core ------------------------------     0 B/152.88 KiB
# google-auth ------------------------------     0 B/204.61 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# psutil     ------------------------------ 14.88 KiB/280.52 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp ------------------------------ 6.84 KiB/6.84 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.88 KiB/18.11 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# importlib-metadata ------------------------------ 25.65 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------     0 B/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 14.87 KiB/62.47 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# anyio      ------------------------------ 11.29 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 30.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 30.86 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/146.18 KiB
# google-api-core ------------------------------ 14.87 KiB/152.88 KiB
# google-auth ------------------------------ 14.87 KiB/204.61 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# psutil     ------------------------------ 16.80 KiB/280.52 KiB
# openai     ------------------------------ 16.00 KiB/380.72 KiB
# langchain-core ------------------------------     0 B/400.05 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp ------------------------------ 6.84 KiB/6.84 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.88 KiB/18.11 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# importlib-metadata ------------------------------ 25.65 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------     0 B/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 14.87 KiB/62.47 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# anyio      ------------------------------ 11.29 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 30.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 30.86 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/146.18 KiB
# google-api-core ------------------------------ 14.87 KiB/152.88 KiB
# google-auth ------------------------------ 14.87 KiB/204.61 KiB
# python-dateutil ------------------------------     0 B/224.50 KiB
# psutil     ------------------------------ 16.80 KiB/280.52 KiB
# openai     ------------------------------ 16.00 KiB/380.72 KiB
# langchain-core ------------------------------     0 B/400.05 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.88 KiB/18.11 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# importlib-metadata ------------------------------ 25.65 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 14.87 KiB/62.47 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# anyio      ------------------------------ 46.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 30.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 92.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 46.87 KiB/152.88 KiB
# google-auth ------------------------------ 30.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 16.00 KiB/224.50 KiB
# psutil     ------------------------------ 48.80 KiB/280.52 KiB
# openai     ------------------------------ 32.00 KiB/380.72 KiB
# langchain-core ------------------------------ 16.00 KiB/400.05 KiB
# pydantic   ------------------------------ 30.88 KiB/446.29 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.88 KiB/18.11 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# importlib-metadata ------------------------------ 25.65 KiB/25.65 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 14.87 KiB/62.47 KiB
# tqdm       ------------------------------ 30.88 KiB/76.70 KiB
# anyio      ------------------------------ 46.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 30.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 92.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 46.87 KiB/152.88 KiB
# google-auth ------------------------------ 30.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 16.00 KiB/224.50 KiB
# psutil     ------------------------------ 48.80 KiB/280.52 KiB
# openai     ------------------------------ 32.00 KiB/380.72 KiB
# langchain-core ------------------------------ 16.00 KiB/400.05 KiB
# pydantic   ------------------------------ 30.88 KiB/446.29 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 18.11 KiB/18.11 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 14.87 KiB/62.47 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# anyio      ------------------------------ 46.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 46.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 108.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 46.87 KiB/152.88 KiB
# google-auth ------------------------------ 46.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 31.89 KiB/224.50 KiB
# psutil     ------------------------------ 64.80 KiB/280.52 KiB
# openai     ------------------------------ 48.00 KiB/380.72 KiB
# langchain-core ------------------------------ 16.00 KiB/400.05 KiB
# pydantic   ------------------------------ 30.88 KiB/446.29 KiB
# regex      ------------------------------ 300.57 KiB/763.38 KiB
# ⠙ Preparing packages... (0/34)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# anyio      ------------------------------ 46.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 46.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 108.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 62.87 KiB/152.88 KiB
# google-auth ------------------------------ 46.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 31.89 KiB/224.50 KiB
# psutil     ------------------------------ 91.30 KiB/280.52 KiB
# openai     ------------------------------ 48.00 KiB/380.72 KiB
# langchain-core ------------------------------ 16.00 KiB/400.05 KiB
# pydantic   ------------------------------ 46.88 KiB/446.29 KiB
# regex      ------------------------------ 365.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.88 KiB/17.43 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# opentelemetry-instrumentation ------------------------------ 28.76 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# anyio      ------------------------------ 46.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 46.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 108.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 62.87 KiB/152.88 KiB
# google-auth ------------------------------ 62.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 31.89 KiB/224.50 KiB
# psutil     ------------------------------ 123.30 KiB/280.52 KiB
# openai     ------------------------------ 48.00 KiB/380.72 KiB
# langchain-core ------------------------------ 16.00 KiB/400.05 KiB
# pydantic   ------------------------------ 62.88 KiB/446.29 KiB
# regex      ------------------------------ 365.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# ⠹ Preparing packages... (5/34)
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# opentelemetry-instrumentation ------------------------------ 28.76 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 14.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 46.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 124.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 62.87 KiB/152.88 KiB
# google-auth ------------------------------ 62.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 47.89 KiB/224.50 KiB
# psutil     ------------------------------ 123.30 KiB/280.52 KiB
# openai     ------------------------------ 48.00 KiB/380.72 KiB
# langchain-core ------------------------------ 32.00 KiB/400.05 KiB
# pydantic   ------------------------------ 77.83 KiB/446.29 KiB
# regex      ------------------------------ 412.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-instrumentation ------------------------------ 28.76 KiB/28.76 KiB
# opentelemetry-proto ------------------------------ 30.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 62.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 46.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 124.00 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/146.18 KiB
# google-api-core ------------------------------ 62.87 KiB/152.88 KiB
# google-auth ------------------------------ 62.87 KiB/204.61 KiB
# python-dateutil ------------------------------ 47.89 KiB/224.50 KiB
# psutil     ------------------------------ 139.30 KiB/280.52 KiB
# openai     ------------------------------ 48.00 KiB/380.72 KiB
# langchain-core ------------------------------ 32.00 KiB/400.05 KiB
# pydantic   ------------------------------ 109.83 KiB/446.29 KiB
# regex      ------------------------------ 460.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 190.91 KiB/1.52 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 30.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 62.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 62.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 128.70 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 22.27 KiB/146.18 KiB
# google-api-core ------------------------------ 62.87 KiB/152.88 KiB
# google-auth ------------------------------ 77.58 KiB/204.61 KiB
# python-dateutil ------------------------------ 222.86 KiB/224.50 KiB
# psutil     ------------------------------ 187.20 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 125.83 KiB/446.29 KiB
# regex      ------------------------------ 489.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 190.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 444.52 KiB/2.04 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 30.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 62.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 62.87 KiB/107.92 KiB
# google-cloud-storage ------------------------------ 128.70 KiB/128.70 KiB
# opentelemetry-semantic-conventions ------------------------------ 22.27 KiB/146.18 KiB
# google-api-core ------------------------------ 78.26 KiB/152.88 KiB
# google-auth ------------------------------ 77.58 KiB/204.61 KiB
# python-dateutil ------------------------------ 222.86 KiB/224.50 KiB
# psutil     ------------------------------ 187.20 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 125.83 KiB/446.29 KiB
# regex      ------------------------------ 489.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 190.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 460.52 KiB/2.04 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 30.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 62.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 62.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 22.27 KiB/146.18 KiB
# google-api-core ------------------------------ 78.26 KiB/152.88 KiB
# google-auth ------------------------------ 77.58 KiB/204.61 KiB
# python-dateutil ------------------------------ 222.86 KiB/224.50 KiB
# psutil     ------------------------------ 187.20 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 125.83 KiB/446.29 KiB
# regex      ------------------------------ 505.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 190.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 460.62 KiB/2.04 MiB
# cryptography ------------------------------ 47.18 KiB/3.97 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 46.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 30.87 KiB/62.47 KiB
# tqdm       ------------------------------ 62.88 KiB/76.70 KiB
# anyio      ------------------------------ 62.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 62.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 22.27 KiB/146.18 KiB
# google-api-core ------------------------------ 78.26 KiB/152.88 KiB
# google-auth ------------------------------ 77.58 KiB/204.61 KiB
# python-dateutil ------------------------------ 222.86 KiB/224.50 KiB
# psutil     ------------------------------ 187.20 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 125.83 KiB/446.29 KiB
# regex      ------------------------------ 505.74 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 62.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 32.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 190.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 460.62 KiB/2.04 MiB
# cryptography ------------------------------ 47.18 KiB/3.97 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 46.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 46.87 KiB/62.47 KiB
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# anyio      ------------------------------ 78.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 78.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 38.27 KiB/146.18 KiB
# google-api-core ------------------------------ 94.26 KiB/152.88 KiB
# google-auth ------------------------------ 93.58 KiB/204.61 KiB
# psutil     ------------------------------ 235.30 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 157.83 KiB/446.29 KiB
# regex      ------------------------------ 556.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 78.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 48.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 238.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 521.38 KiB/2.04 MiB
# cryptography ------------------------------ 583.93 KiB/3.97 MiB
# pandas     ------------------------------ 144.00 KiB/12.46 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 46.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 46.87 KiB/62.47 KiB
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# anyio      ------------------------------ 78.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 78.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 38.27 KiB/146.18 KiB
# google-api-core ------------------------------ 94.26 KiB/152.88 KiB
# google-auth ------------------------------ 93.58 KiB/204.61 KiB
# psutil     ------------------------------ 235.30 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 157.83 KiB/446.29 KiB
# regex      ------------------------------ 588.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 78.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 48.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 238.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 572.62 KiB/2.04 MiB
# cryptography ------------------------------ 636.87 KiB/3.97 MiB
# pandas     ------------------------------ 144.00 KiB/12.46 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-proto ------------------------------ 46.90 KiB/51.23 KiB
# opentelemetry-api ------------------------------ 62.47 KiB/62.47 KiB
# anyio      ------------------------------ 78.88 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 78.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 38.27 KiB/146.18 KiB
# google-api-core ------------------------------ 94.26 KiB/152.88 KiB
# google-auth ------------------------------ 93.58 KiB/204.61 KiB
# psutil     ------------------------------ 235.30 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 157.83 KiB/446.29 KiB
# regex      ------------------------------ 620.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 78.77 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 48.29 KiB/1.50 MiB
# aiohttp    ------------------------------ 238.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 572.62 KiB/2.04 MiB
# cryptography ------------------------------ 636.87 KiB/3.97 MiB
# pandas     ------------------------------ 160.00 KiB/12.46 MiB
# pyarrow    ------------------------------ 636.82 KiB/38.20 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-api ------------------------------ 62.47 KiB/62.47 KiB
# anyio      ------------------------------ 90.87 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 94.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 54.27 KiB/146.18 KiB
# google-api-core ------------------------------ 94.26 KiB/152.88 KiB
# google-auth ------------------------------ 109.58 KiB/204.61 KiB
# psutil     ------------------------------ 263.43 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 157.83 KiB/446.29 KiB
# regex      ------------------------------ 636.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 94.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 608.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 254.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 588.62 KiB/2.04 MiB
# cryptography ------------------------------ 652.87 KiB/3.97 MiB
# pandas     ------------------------------ 176.00 KiB/12.46 MiB
# pyarrow    ------------------------------ 652.82 KiB/38.20 MiB
# ⠹ Preparing packages... (5/34)
# opentelemetry-api ------------------------------ 62.47 KiB/62.47 KiB
# anyio      ------------------------------ 90.87 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 94.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 54.27 KiB/146.18 KiB
# google-api-core ------------------------------ 94.26 KiB/152.88 KiB
# google-auth ------------------------------ 109.58 KiB/204.61 KiB
# psutil     ------------------------------ 263.43 KiB/280.52 KiB
# openai     ------------------------------ 61.89 KiB/380.72 KiB
# langchain-core ------------------------------ 47.89 KiB/400.05 KiB
# pydantic   ------------------------------ 157.83 KiB/446.29 KiB
# regex      ------------------------------ 668.57 KiB/763.38 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 94.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 608.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 254.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 588.62 KiB/2.04 MiB
# cryptography ------------------------------ 668.98 KiB/3.97 MiB
# pandas     ------------------------------ 176.00 KiB/12.46 MiB
# pyarrow    ------------------------------ 668.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-api ------------------------------ 62.47 KiB/62.47 KiB
# anyio      ------------------------------ 90.87 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 94.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 110.26 KiB/152.88 KiB
# google-auth ------------------------------ 125.58 KiB/204.61 KiB
# psutil     ------------------------------ 280.52 KiB/280.52 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 60.52 KiB/400.05 KiB
# pydantic   ------------------------------ 173.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 126.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 784.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 270.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 753.13 KiB/2.04 MiB
# cryptography ------------------------------ 812.98 KiB/3.97 MiB
# pandas     ------------------------------ 265.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 828.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-api ------------------------------ 62.47 KiB/62.47 KiB
# anyio      ------------------------------ 90.87 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 94.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 110.26 KiB/152.88 KiB
# google-auth ------------------------------ 125.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 60.52 KiB/400.05 KiB
# pydantic   ------------------------------ 189.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 126.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 784.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 270.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 753.13 KiB/2.04 MiB
# cryptography ------------------------------ 812.98 KiB/3.97 MiB
# pandas     ------------------------------ 265.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 828.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# anyio      ------------------------------ 90.87 KiB/90.87 KiB
# opentelemetry-sdk ------------------------------ 94.87 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 110.26 KiB/152.88 KiB
# google-auth ------------------------------ 125.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 60.52 KiB/400.05 KiB
# pydantic   ------------------------------ 189.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 126.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 800.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 270.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 785.13 KiB/2.04 MiB
# cryptography ------------------------------ 844.98 KiB/3.97 MiB
# pandas     ------------------------------ 265.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 844.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-sdk ------------------------------ 107.92 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 126.26 KiB/152.88 KiB
# google-auth ------------------------------ 125.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 60.52 KiB/400.05 KiB
# pydantic   ------------------------------ 189.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 126.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 800.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 270.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 785.13 KiB/2.04 MiB
# cryptography ------------------------------ 844.98 KiB/3.97 MiB
# pandas     ------------------------------ 293.83 KiB/12.46 MiB
# pyarrow    ------------------------------ 844.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-sdk ------------------------------ 107.92 KiB/107.92 KiB
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 126.26 KiB/152.88 KiB
# google-auth ------------------------------ 125.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 60.52 KiB/400.05 KiB
# pydantic   ------------------------------ 189.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 142.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 800.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 270.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 785.13 KiB/2.04 MiB
# cryptography ------------------------------ 844.98 KiB/3.97 MiB
# pandas     ------------------------------ 293.83 KiB/12.46 MiB
# pyarrow    ------------------------------ 860.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 126.26 KiB/152.88 KiB
# google-auth ------------------------------ 141.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 76.52 KiB/400.05 KiB
# pydantic   ------------------------------ 221.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 158.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 800.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 302.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 812.62 KiB/2.04 MiB
# cryptography ------------------------------ 876.98 KiB/3.97 MiB
# pandas     ------------------------------ 309.83 KiB/12.46 MiB
# pyarrow    ------------------------------ 876.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-semantic-conventions ------------------------------ 70.27 KiB/146.18 KiB
# google-api-core ------------------------------ 126.26 KiB/152.88 KiB
# google-auth ------------------------------ 141.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 76.52 KiB/400.05 KiB
# pydantic   ------------------------------ 221.83 KiB/446.29 KiB
# langchain  ------------------------------ 32.00 KiB/985.38 KiB
# setuptools ------------------------------ 158.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 816.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 302.91 KiB/1.52 MiB
# pydantic-core ------------------------------ 812.62 KiB/2.04 MiB
# cryptography ------------------------------ 876.98 KiB/3.97 MiB
# pandas     ------------------------------ 309.83 KiB/12.46 MiB
# pyarrow    ------------------------------ 876.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/146.18 KiB
# google-auth ------------------------------ 157.58 KiB/204.61 KiB
# openai     ------------------------------ 77.89 KiB/380.72 KiB
# langchain-core ------------------------------ 108.42 KiB/400.05 KiB
# pydantic   ------------------------------ 253.61 KiB/446.29 KiB
# langchain  ------------------------------ 48.00 KiB/985.38 KiB
# setuptools ------------------------------ 190.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 816.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 952.35 KiB/1.52 MiB
# pydantic-core ------------------------------ 860.62 KiB/2.04 MiB
# cryptography ------------------------------ 940.98 KiB/3.97 MiB
# pandas     ------------------------------ 393.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 940.82 KiB/38.20 MiB
# ⠸ Preparing packages... (12/34)
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/146.18 KiB
# google-auth ------------------------------ 157.58 KiB/204.61 KiB
# openai     ------------------------------ 93.89 KiB/380.72 KiB
# langchain-core ------------------------------ 108.42 KiB/400.05 KiB
# pydantic   ------------------------------ 253.61 KiB/446.29 KiB
# langchain  ------------------------------ 48.00 KiB/985.38 KiB
# setuptools ------------------------------ 190.88 KiB/1.17 MiB
# keras      ------------------------------ 16.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 816.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 963.56 KiB/1.52 MiB
# pydantic-core ------------------------------ 956.62 KiB/2.04 MiB
# cryptography ------------------------------ 940.98 KiB/3.97 MiB
# pandas     ------------------------------ 393.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 945.50 KiB/38.20 MiB
# ⠼ Preparing packages... (19/34)
# opentelemetry-semantic-conventions ------------------------------ 96.00 KiB/146.18 KiB
# google-auth ------------------------------ 204.61 KiB/204.61 KiB
# openai     ------------------------------ 141.89 KiB/380.72 KiB
# langchain-core ------------------------------ 140.52 KiB/400.05 KiB
# pydantic   ------------------------------ 285.83 KiB/446.29 KiB
# langchain  ------------------------------ 48.00 KiB/985.38 KiB
# setuptools ------------------------------ 286.88 KiB/1.17 MiB
# keras      ------------------------------ 32.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 848.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 1.16 MiB/1.52 MiB
# pydantic-core ------------------------------ 1.11 MiB/2.04 MiB
# cryptography ------------------------------ 1.17 MiB/3.97 MiB
# pandas     ------------------------------ 489.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 1.15 MiB/38.20 MiB
# ⠼ Preparing packages... (19/34)
# opentelemetry-semantic-conventions ------------------------------ 96.00 KiB/146.18 KiB
# openai     ------------------------------ 141.89 KiB/380.72 KiB
# langchain-core ------------------------------ 140.52 KiB/400.05 KiB
# pydantic   ------------------------------ 285.83 KiB/446.29 KiB
# langchain  ------------------------------ 48.00 KiB/985.38 KiB
# setuptools ------------------------------ 301.63 KiB/1.17 MiB
# keras      ------------------------------ 32.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 848.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 1.16 MiB/1.52 MiB
# pydantic-core ------------------------------ 1.11 MiB/2.04 MiB
# cryptography ------------------------------ 1.17 MiB/3.97 MiB
# pandas     ------------------------------ 489.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 1.15 MiB/38.20 MiB
# ⠼ Preparing packages... (19/34)
# openai     ------------------------------ 173.89 KiB/380.72 KiB
# langchain-core ------------------------------ 156.52 KiB/400.05 KiB
# pydantic   ------------------------------ 365.83 KiB/446.29 KiB
# langchain  ------------------------------ 63.95 KiB/985.38 KiB
# setuptools ------------------------------ 333.63 KiB/1.17 MiB
# keras      ------------------------------ 32.00 KiB/1.17 MiB
# llama-index-core ------------------------------ 864.00 KiB/1.50 MiB
# aiohttp    ------------------------------ 1.28 MiB/1.52 MiB
# pydantic-core ------------------------------ 1.24 MiB/2.04 MiB
# cryptography ------------------------------ 1.29 MiB/3.97 MiB
# pandas     ------------------------------ 537.81 KiB/12.46 MiB
# pyarrow    ------------------------------ 1.30 MiB/38.20 MiB
# ⠼ Preparing packages... (19/34)
# openai     ------------------------------ 189.89 KiB/380.72 KiB
# langchain-core ------------------------------ 186.23 KiB/400.05 KiB
# pydantic   ------------------------------ 406.73 KiB/446.29 KiB
# ...
# keras      ------------------------------ 510.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.22 MiB/1.50 MiB
# cryptography ------------------------------ 3.96 MiB/3.97 MiB
# pandas     ------------------------------ 1.32 MiB/12.46 MiB
# pyarrow    ------------------------------ 8.73 MiB/38.20 MiB
# ⠇ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.05 MiB/1.17 MiB
# keras      ------------------------------ 534.03 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.22 MiB/1.50 MiB
# cryptography ------------------------------ 3.97 MiB/3.97 MiB
# pandas     ------------------------------ 1.38 MiB/12.46 MiB
# pyarrow    ------------------------------ 8.95 MiB/38.20 MiB
# ⠇ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.07 MiB/1.17 MiB
# keras      ------------------------------ 534.03 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.22 MiB/1.50 MiB
# cryptography ------------------------------ 3.97 MiB/3.97 MiB
# pandas     ------------------------------ 1.38 MiB/12.46 MiB
# pyarrow    ------------------------------ 10.10 MiB/38.20 MiB
# ⠇ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.07 MiB/1.17 MiB
# keras      ------------------------------ 534.03 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.22 MiB/1.50 MiB
# cryptography ------------------------------ 3.97 MiB/3.97 MiB
# pandas     ------------------------------ 1.40 MiB/12.46 MiB
# pyarrow    ------------------------------ 10.74 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.07 MiB/1.17 MiB
# keras      ------------------------------ 550.03 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.22 MiB/1.50 MiB
# pandas     ------------------------------ 1.43 MiB/12.46 MiB
# pyarrow    ------------------------------ 10.74 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.08 MiB/1.17 MiB
# keras      ------------------------------ 550.03 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.23 MiB/1.50 MiB
# pandas     ------------------------------ 1.43 MiB/12.46 MiB
# pyarrow    ------------------------------ 11.41 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 351.95 KiB/985.38 KiB
# setuptools ------------------------------ 1.10 MiB/1.17 MiB
# keras      ------------------------------ 606.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.25 MiB/1.50 MiB
# pandas     ------------------------------ 1.48 MiB/12.46 MiB
# pyarrow    ------------------------------ 11.87 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 367.84 KiB/985.38 KiB
# setuptools ------------------------------ 1.11 MiB/1.17 MiB
# keras      ------------------------------ 606.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.25 MiB/1.50 MiB
# pandas     ------------------------------ 1.48 MiB/12.46 MiB
# pyarrow    ------------------------------ 11.98 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 367.84 KiB/985.38 KiB
# keras      ------------------------------ 638.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.27 MiB/1.50 MiB
# pandas     ------------------------------ 1.49 MiB/12.46 MiB
# pyarrow    ------------------------------ 12.03 MiB/38.20 MiB
# ⠋ Preparing packages... (26/34)
# langchain  ------------------------------ 367.84 KiB/985.38 KiB
# keras      ------------------------------ 654.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.29 MiB/1.50 MiB
# pandas     ------------------------------ 1.51 MiB/12.46 MiB
# pyarrow    ------------------------------ 12.69 MiB/38.20 MiB
# ⠙ Preparing packages... (28/34)
# langchain  ------------------------------ 383.84 KiB/985.38 KiB
# keras      ------------------------------ 702.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.31 MiB/1.50 MiB
# pandas     ------------------------------ 1.57 MiB/12.46 MiB
# pyarrow    ------------------------------ 13.45 MiB/38.20 MiB
# ⠙ Preparing packages... (28/34)
# langchain  ------------------------------ 399.84 KiB/985.38 KiB
# keras      ------------------------------ 750.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.33 MiB/1.50 MiB
# pandas     ------------------------------ 1.68 MiB/12.46 MiB
# pyarrow    ------------------------------ 14.04 MiB/38.20 MiB
# ⠙ Preparing packages... (28/34)
# langchain  ------------------------------ 399.84 KiB/985.38 KiB
# keras      ------------------------------ 862.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.37 MiB/1.50 MiB
# pandas     ------------------------------ 1.73 MiB/12.46 MiB
# pyarrow    ------------------------------ 14.70 MiB/38.20 MiB
# ⠙ Preparing packages... (28/34)
# langchain  ------------------------------ 415.95 KiB/985.38 KiB
# keras      ------------------------------ 933.80 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.37 MiB/1.50 MiB
# pandas     ------------------------------ 1.76 MiB/12.46 MiB
# pyarrow    ------------------------------ 15.22 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 431.95 KiB/985.38 KiB
# keras      ------------------------------ 1022.83 KiB/1.17 MiB
# llama-index-core ------------------------------ 1.41 MiB/1.50 MiB
# pandas     ------------------------------ 1.86 MiB/12.46 MiB
# pyarrow    ------------------------------ 15.88 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 447.95 KiB/985.38 KiB
# keras      ------------------------------ 1.04 MiB/1.17 MiB
# pandas     ------------------------------ 1.92 MiB/12.46 MiB
# pyarrow    ------------------------------ 16.58 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 447.95 KiB/985.38 KiB
# keras      ------------------------------ 1.06 MiB/1.17 MiB
# pandas     ------------------------------ 1.92 MiB/12.46 MiB
# pyarrow    ------------------------------ 16.67 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 447.95 KiB/985.38 KiB
# keras      ------------------------------ 1.10 MiB/1.17 MiB
# pandas     ------------------------------ 1.94 MiB/12.46 MiB
# pyarrow    ------------------------------ 17.49 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 463.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.00 MiB/12.46 MiB
# pyarrow    ------------------------------ 18.00 MiB/38.20 MiB
# ⠹ Preparing packages... (28/34)
# langchain  ------------------------------ 479.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.01 MiB/12.46 MiB
# pyarrow    ------------------------------ 18.40 MiB/38.20 MiB
# ⠸ Preparing packages... (30/34)
# langchain  ------------------------------ 495.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.08 MiB/12.46 MiB
# pyarrow    ------------------------------ 19.92 MiB/38.20 MiB
# ⠸ Preparing packages... (30/34)
# langchain  ------------------------------ 511.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.13 MiB/12.46 MiB
# pyarrow    ------------------------------ 21.42 MiB/38.20 MiB
# ⠸ Preparing packages... (30/34)
# langchain  ------------------------------ 527.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.16 MiB/12.46 MiB
# pyarrow    ------------------------------ 22.55 MiB/38.20 MiB
# ⠸ Preparing packages... (30/34)
# langchain  ------------------------------ 543.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.19 MiB/12.46 MiB
# pyarrow    ------------------------------ 23.52 MiB/38.20 MiB
# ⠼ Preparing packages... (30/34)
# langchain  ------------------------------ 543.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.19 MiB/12.46 MiB
# pyarrow    ------------------------------ 24.26 MiB/38.20 MiB
# ⠼ Preparing packages... (30/34)
# langchain  ------------------------------ 543.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.26 MiB/12.46 MiB
# pyarrow    ------------------------------ 26.26 MiB/38.20 MiB
# ⠼ Preparing packages... (30/34)
# langchain  ------------------------------ 575.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.33 MiB/12.46 MiB
# pyarrow    ------------------------------ 27.68 MiB/38.20 MiB
# ⠼ Preparing packages... (30/34)
# langchain  ------------------------------ 591.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.44 MiB/12.46 MiB
# pyarrow    ------------------------------ 29.04 MiB/38.20 MiB
# ⠴ Preparing packages... (30/34)
# langchain  ------------------------------ 607.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.55 MiB/12.46 MiB
# pyarrow    ------------------------------ 30.37 MiB/38.20 MiB
# ⠴ Preparing packages... (30/34)
# langchain  ------------------------------ 639.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.65 MiB/12.46 MiB
# pyarrow    ------------------------------ 31.48 MiB/38.20 MiB
# ⠴ Preparing packages... (30/34)
# langchain  ------------------------------ 639.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.68 MiB/12.46 MiB
# pyarrow    ------------------------------ 32.68 MiB/38.20 MiB
# ⠴ Preparing packages... (30/34)
# langchain  ------------------------------ 639.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.70 MiB/12.46 MiB
# pyarrow    ------------------------------ 34.27 MiB/38.20 MiB
# ⠦ Preparing packages... (30/34)
# langchain  ------------------------------ 655.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.70 MiB/12.46 MiB
# pyarrow    ------------------------------ 35.06 MiB/38.20 MiB
# ⠦ Preparing packages... (30/34)
# langchain  ------------------------------ 655.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.72 MiB/12.46 MiB
# pyarrow    ------------------------------ 35.94 MiB/38.20 MiB
# ⠦ Preparing packages... (30/34)
# langchain  ------------------------------ 655.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.76 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.18 MiB/38.20 MiB
# ⠦ Preparing packages... (30/34)
# langchain  ------------------------------ 655.95 KiB/985.38 KiB
# pandas     ------------------------------ 2.82 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.36 MiB/38.20 MiB
# ⠧ Preparing packages... (30/34)
# langchain  ------------------------------ 700.80 KiB/985.38 KiB
# pandas     ------------------------------ 2.91 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.42 MiB/38.20 MiB
# ⠧ Preparing packages... (30/34)
# langchain  ------------------------------ 732.80 KiB/985.38 KiB
# pandas     ------------------------------ 2.97 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.50 MiB/38.20 MiB
# ⠧ Preparing packages... (30/34)
# langchain  ------------------------------ 732.80 KiB/985.38 KiB
# pandas     ------------------------------ 3.03 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.58 MiB/38.20 MiB
# ⠧ Preparing packages... (30/34)
# langchain  ------------------------------ 751.95 KiB/985.38 KiB
# pandas     ------------------------------ 3.14 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.65 MiB/38.20 MiB
# ⠇ Preparing packages... (30/34)
# langchain  ------------------------------ 751.95 KiB/985.38 KiB
# pandas     ------------------------------ 3.21 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.73 MiB/38.20 MiB
# ⠇ Preparing packages... (30/34)
# langchain  ------------------------------ 767.95 KiB/985.38 KiB
# pandas     ------------------------------ 3.65 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.86 MiB/38.20 MiB
# ⠇ Preparing packages... (30/34)
# langchain  ------------------------------ 783.38 KiB/985.38 KiB
# pandas     ------------------------------ 3.89 MiB/12.46 MiB
# pyarrow    ------------------------------ 36.95 MiB/38.20 MiB
# ⠇ Preparing packages... (30/34)
# langchain  ------------------------------ 799.38 KiB/985.38 KiB
# pandas     ------------------------------ 4.07 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.06 MiB/38.20 MiB
# ⠋ Preparing packages... (30/34)
# langchain  ------------------------------ 815.95 KiB/985.38 KiB
# pandas     ------------------------------ 4.38 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.17 MiB/38.20 MiB
# ⠋ Preparing packages... (30/34)
# pandas     ------------------------------ 4.43 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.29 MiB/38.20 MiB
# ⠋ Preparing packages... (30/34)
# pandas     ------------------------------ 4.46 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.34 MiB/38.20 MiB
# ⠋ Preparing packages... (30/34)
# pandas     ------------------------------ 5.89 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.47 MiB/38.20 MiB
# ⠋ Preparing packages... (30/34)
# pandas     ------------------------------ 7.73 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.58 MiB/38.20 MiB
# ⠙ Preparing packages... (31/34)
# pandas     ------------------------------ 8.86 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.70 MiB/38.20 MiB
# ⠙ Preparing packages... (31/34)
# pandas     ------------------------------ 9.66 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.83 MiB/38.20 MiB
# ⠙ Preparing packages... (31/34)
# pandas     ------------------------------ 11.03 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.89 MiB/38.20 MiB
# ⠙ Preparing packages... (31/34)
# pandas     ------------------------------ 11.97 MiB/12.46 MiB
# pyarrow    ------------------------------ 37.93 MiB/38.20 MiB
# ⠹ Preparing packages... (31/34)
# pyarrow    ------------------------------ 38.03 MiB/38.20 MiB
# ⠹ Preparing packages... (31/34)
# pyarrow    ------------------------------ 38.15 MiB/38.20 MiB
# ⠹ Preparing packages... (31/34)
# ⠹ Preparing packages... (31/34)
# ⠹ Preparing packages... (31/34)
# Prepared 34 packages in 3.98s
# Uninstalled 34 packages in 801ms
# Installed 34 packages in 458ms
#  - aiohttp==3.11.9
#  + aiohttp==3.11.10
#  - anyio==3.7.1
#  + anyio==4.7.0
#  - cryptography==43.0.3
#  + cryptography==44.0.0
#  - decorator==4.4.2
#  + decorator==5.1.1
#  - google-api-core==2.19.2
#  + google-api-core==2.23.0
#  - google-auth==2.27.0
#  + google-auth==2.36.0
#  - google-cloud-storage==2.8.0
#  + google-cloud-storage==2.19.0
#  - importlib-metadata==8.5.0
#  + importlib-metadata==8.4.0
#  - keras==3.5.0
#  + keras==3.7.0
#  - langchain==0.3.9
#  + langchain==0.3.10
#  - langchain-core==0.3.21
#  + langchain-core==0.3.22
#  - llama-index-core==0.12.3
#  + llama-index-core==0.12.0
#  - openai==1.54.5
#  + openai==1.57.0
#  - opentelemetry-api==1.28.2
#  + opentelemetry-api==1.27.0
#  - opentelemetry-exporter-otlp==1.28.2
#  + opentelemetry-exporter-otlp==1.27.0
#  - opentelemetry-exporter-otlp-proto-common==1.28.2
#  + opentelemetry-exporter-otlp-proto-common==1.27.0
#  - opentelemetry-exporter-otlp-proto-grpc==1.28.2
#  + opentelemetry-exporter-otlp-proto-grpc==1.27.0
#  - opentelemetry-exporter-otlp-proto-http==1.28.2
#  + opentelemetry-exporter-otlp-proto-http==1.27.0
#  - opentelemetry-instrumentation==0.49b2
#  + opentelemetry-instrumentation==0.48b0
#  - opentelemetry-proto==1.28.2
#  + opentelemetry-proto==1.27.0
#  - opentelemetry-sdk==1.28.2
#  + opentelemetry-sdk==1.27.0
#  - opentelemetry-semantic-conventions==0.49b2
#  + opentelemetry-semantic-conventions==0.48b0
#  - pandas==2.2.2
#  + pandas==2.2.3
#  - psutil==5.9.5
#  + psutil==6.1.0
#  - pyarrow==17.0.0
#  + pyarrow==18.1.0
#  - pydantic==2.9.2
#  + pydantic==2.10.3
#  - pydantic-core==2.23.4
#  + pydantic-core==2.27.1
#  - python-dateutil==2.8.2
#  + python-dateutil==2.9.0.post0
#  - regex==2024.9.11
#  + regex==2024.11.6
#  - requests-oauthlib==1.3.1
#  + requests-oauthlib==2.0.0
#  - scipy==1.13.1
#  + scipy==1.14.1
#  - setuptools==75.1.0
#  + setuptools==75.6.0
#  - six==1.16.0
#  + six==1.17.0
#  - tqdm==4.66.6
#  + tqdm==4.67.1

# %%
import os
from getpass import getpass

if not (openai_api_key := os.getenv("OPENAI_API_KEY")):
    openai_api_key = getpass("🔑 Enter your OpenAI API key: ")

os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
import nest_asyncio
import pandas as pd

from phoenix.evals import (
    TOOL_CALLING_PROMPT_RAILS_MAP,
    TOOL_CALLING_PROMPT_TEMPLATE,
    OpenAIModel,
    llm_classify,
)

nest_asyncio.apply()

# %% [markdown]
# # Generate App Usage Data
#
# Let's begin by generating some data to use for our evaluation. Let's pretend we have a chatbot for an ecommerce company that is armed with a set of functions to lookup products and orders.

# %%
GEN_TEMPLATE = """
You are an assistant that generates complex customer service questions. You will try to answer the question with the tool if possible,
do your best to answer, ask for more information only if needed.
The questions should often involve:

Please reference the product names, the product details, product IDS and product information.

Multiple Categories: Questions that could logically fall into more than one category (e.g., combining product details with a discount code).
Vague Details: Questions with limited or vague information that require clarification to categorize correctly.
Mixed Intentions: Queries where the customer’s goal or need is unclear or seems to conflict within the question itself.
Indirect Language: Use of indirect or polite phrasing that obscures the direct need or request (e.g., using "I was wondering if..." or "Perhaps you could help me with...").
For specific categories:

Track Package: Include vague timing references (e.g., "recently" or "a while ago") instead of specific dates.
Product Comparison and Product Search: Include generic descriptors without specific product names or IDs (e.g., "high-end smartphones" or "energy-efficient appliances").
Apply Discount Code: Include questions about discounts that might apply to hypothetical or past situations, or without mentioning if they have made a purchase.
Product Details: Ask for comparisons or details that involve multiple products or categories ambiguously (e.g., "Tell me about your range of electronics that are good for home office setups").
Examples of More Challenging Questions
Multiple Categories

"I recently bought a samsung 106i smart phone, and I was wondering if there's a way to check what deals I might have missed or if my order is on its way?"
"Could you tell me if the samsung 15H adapater in my last order are covered under warranty and if they have shipped yet?"
Vague Details

"There's an issue with one of the Vizio 14Y TV I think I bought last month—what should I do?"
"I need help with a iPhone 16H I ordered, or maybe I'm just looking for something new. Can you help?"
Mixed Intentions

"I'm not sure if I should ask for a refund or just find out when it will arrive. What do you suggest?"
"Could you help me decide whether to upgrade my product or just track the current one?"
Indirect Language

"I was wondering if you might assist me in figuring out a problem I have with an order, or maybe it's more of a query?"
"Perhaps you could help me understand the benefits of your premium products compared to the regular ones?"

Some questions should be straightforward uses of the provided functions

Respond with a list, one question per line. Do not include any numbering at the beginning of each line. Do not include any category headings.
Generate 20 questions.
"""

# %%
model = OpenAIModel(model="gpt-4o", max_tokens=1300)

# %%
resp = model(GEN_TEMPLATE)

# %%
split_response = resp.strip().split("\n")

questions_df = pd.DataFrame(split_response, columns=["questions"])
print(questions_df)

# %% [markdown]
# # Define a tool-calling agent with Langchain
#
# Now we'll define the chatbot agent using Langchain to attach the functions as tools.

# %%
from langchain.agents import AgentType, initialize_agent
from langchain.prompts.chat import ChatPromptTemplate, MessagesPlaceholder
from langchain.tools import tool
from langchain_openai import ChatOpenAI
from openinference.instrumentation.langchain import LangChainInstrumentor

import phoenix as px
from phoenix.otel import register

# %% [markdown]
# We'll also enable tracing with Phoenix using our Langchain auto-instrumentor to capture telemetry that we can later evaluate.

# %%
(session := px.launch_app()).view()
tracer_provider = register()
LangChainInstrumentor(tracer_provider=tracer_provider).instrument(skip_dep_check=True)

# %% [markdown]
# Now we'll define our basic functions using pydantic. The actual logic of the functions doesn't matter in this evaluation scenario, since we won't be evaluating anything beyond the function generation step.

# %%
## function definitions using pydantic decorator


@tool
def product_comparison(product_a_id: str, product_b_id: str) -> dict:
    """
    Compare features of two products.

    Parameters:
    product_a_id (str): The unique identifier of Product A.
    product_b_id (str): The unique identifier of Product B.

    Returns:
    dict: A dictionary containing the comparison of the two products.
    """

    if product_a_id == "" or product_b_id == "":
        return {"error": "missing product id"}

    # Implement the function logic here
    return {"comparison": "Similar"}


@tool
def product_details(product_id: str) -> dict:
    """
    Get detailed features on one product.

    Parameters:
    product_id (str): The unique identifier of the Product.

    Returns:
    dict: A dictionary containing product details.
    """

    if product_id == "":
        return {"error": "missing product id"}

    # Implement the function logic here
    return {"name": "Product Name", "price": "$12.50", "Availability": "In Stock"}


@tool
def apply_discount_code(order_id: int, discount_code: str) -> dict:
    """
    Applies a discount code to an order.

    Parameters:
    order_id (str): The unique identifier of the order.
    discount_code (str): The discount code to apply.

    Returns:
    dict: A dictionary containing the updated order details.
    """

    if order_id == "" or discount_code == "":
        return {"error": "missing order id or discount code"}

    # Implement the function logic here
    return {"applied": "True"}


@tool
def product_search(
    query: str,
    category: str = None,
    min_price: float = 0.0,
    max_price: float = None,
    page: int = 1,
    page_size: int = 20,
) -> dict:
    """
    Search for products based on criteria.

    Parameters:
    query (str): The search query string.
    category (str, optional): The category to filter the search. Default is None.
    min_price (float, optional): The minimum price of the products to search. Default is 0.
    max_price (float, optional): The maximum price of the products to search. Default is None.
    page (int, optional): The page number for pagination. Default is 1.
    page_size (int, optional): The number of results per page. Default is 20.

    Returns:
    dict: A dictionary containing the search results and pagination info.
    """

    if query == "":
        return {"error": "missing query"}

    # Implement the function logic here
    return {"results": [], "pagination": {"total": 0, "page": 1, "page_size": 20}}


@tool
def customer_support(issue_type: str) -> dict:
    """
    Get contact information for customer support regarding an issue.

    Parameters:
    issue_type (str): The type of issue (e.g., billing, technical support).

    Returns:
    dict: A dictionary containing the contact information for customer support.
    """

    if issue_type == "":
        return {"error": "missing issue type"}

    # Implement the function logic here
    return {"contact": issue_type}


@tool
def track_package(tracking_number: int) -> dict:
    """
    Track the status of a package based on the tracking number.

    Parameters:
    tracking_number (str): The tracking number of the package.

    Returns:
    dict: A dictionary containing the tracking status of the package.
    """
    if tracking_number == "":
        return {"error": "missing tracking number"}

    # Implement the function logic here
    return {"status": "Delivered"}


tools = [
    product_comparison,
    product_search,
    customer_support,
    track_package,
    apply_discount_code,
    product_details,
]

# %%
llm = ChatOpenAI(model="gpt-4o")
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant"),
        ("human", "{input}"),
        MessagesPlaceholder(variable_name="agent_scratchpad"),
    ]
)

# %%
agent_executor = initialize_agent(tools, llm, agent=AgentType.OPENAI_FUNCTIONS)

# %% [markdown]
# # Run Agent on each question
#
# With our agent defined, we can now run it across each generated question.

# %%
questions_df["response"] = questions_df["questions"].apply(agent_executor.invoke)

# %%
questions_df

# %% [markdown]
# # Evaluate Tool Calls
#
# Now that we have some example runs of our agent to analyze, we can start the evaluation process. We'll start by exporting all of those spans from Phoenix

# %%
from phoenix.trace import SpanEvaluations
from phoenix.trace.dsl import SpanQuery

# %% [markdown]
# Since we'll only be evaluating the inputs, outputs, and function call columns, let's extract those into an easier to use df. Helpfully, Phoenix provides a method to query your span data and directly export only the values you care about.

# %%
query = (
    SpanQuery()
    .where(
        # Filter for the `LLM` span kind.
        # The filter condition is a string of valid Python boolean expression.
        "span_kind == 'LLM'",
    )
    .select(
        # Extract and rename the following span attributes
        question="llm.input_messages",
        response="llm.output_messages",
        tool_call="llm.function_call",
    )
)
trace_df = px.Client().query_spans(query)
trace_df["tool_call"] = trace_df["tool_call"].fillna("No tool used")

# %%
trace_df

# %% [markdown]
# We'll also need to pass in our tool definitions to the evaluator. We've found this works best when formatted as a JSON object matching the format your agent's underlying model uses (e.g. https://platform.openai.com/docs/guides/function-calling for OpenAI).

# %%
# @title JSON Function / Tool
json_tools = """
tools = [
    {
        "name": "product_comparison",
        "description": "Compare features of two products.",
        "parameters": {
            "type": "object",
            "properties": {
                "product_a_id": {
                    "type": "string",
                    "description": "The unique identifier of Product A."
                },
                "product_b_id": {
                    "type": "string",
                    "description": "The unique identifier of Product B."
                }
            },
            "required": ["product_a_id", "product_b_id"]
        }
    },
    {
        "name": "product_search",
        "description": "Search for products based on criteria.",
        "parameters": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "description": "The search query string."
                },
                "category": {
                    "type": "string",
                    "description": "The category to filter the search.",
                    "default": None
                },
                "min_price": {
                    "type": "number",
                    "description": "The minimum price of the products to search.",
                    "default": 0
                },
                "max_price": {
                    "type": "number",
                    "description": "The maximum price of the products to search.",
                    "default": None
                },
                "page": {
                    "type": "integer",
                    "description": "The page number for pagination.",
                    "default": 1
                },
                "page_size": {
                    "type": "integer",
                    "description": "The number of results per page.",
                    "default": 20
                }
            },
            "required": ["query"]
        }
    },
    {
        "name": "customer_support",
        "description": "Get contact information for customer support regarding an issue.",
        "parameters": {
            "type": "object",
            "properties": {
                "issue_type": {
                    "type": "string",
                    "description": "The type of issue (e.g., billing, technical support)."
                }
            },
            "required": ["issue_type"]
        }
    },
    {
        "name": "track_package",
        "description": "Track the status of a package based on the tracking number.",
        "parameters": {
            "type": "object",
            "properties": {
                "tracking_number": {
                    "type": "integer",
                    "description": "The tracking number of the package."
                }
            },
            "required": ["tracking_number"]
        }
    },
    {
        "name": "product_details",
        "description": "Returns details for a given product id",
        "parameters": {
            "type": "object",
            "properties": {
                "product_id": {
                    "type": "string",
                    "description": "The id of a product to look up."
                }
            },
            "required": ["product_id"]
        }
    },
    {
        "name": "apply_discount_code",
        "description": "Applies the discount code to a given order.",
        "parameters": {
            "type": "object",
            "properties": {
                "order_id": {
                    "type": "integer",
                    "description": "The id of the order to apply the discount code to."
                },
                "discount_code": {
                    "type": "string",
                    "description": "The discount code to apply
                }
            },
            "required": ["order_id, discount_code"]
        }
    }
]

"""

# %% [markdown]
# Next, we define the evaluator model to use

# %%
eval_model = OpenAIModel(model="gpt-4o")

# %% [markdown]
# And we're ready to call our evaluator! The method below takes in the dataframe of traces to evaluate, our built in evaluation prompt, the eval model to use, and a rails object to snap responses from our model to a set of binary classification responses.
#
# We'll also instruct our model to provide explanations for its responses.

# %%
rails = list(TOOL_CALLING_PROMPT_RAILS_MAP.values())

response_classifications = llm_classify(
    dataframe=trace_df,
    template=TOOL_CALLING_PROMPT_TEMPLATE.template.replace("{tool_definitions}", json_tools),
    model=eval_model,
    rails=rails,
    provide_explanation=True,
)

# %%
response_classifications

# %% [markdown]
# Finally, we'll export these responses back into Phoenix to view them in the UI.

# %%
px.Client().log_evaluations(
    SpanEvaluations(eval_name="Tool Calling Eval", dataframe=response_classifications),
)

# %%
print("View your evals in the Spans section of the UI here:", px.Client().web_url)

# %% [markdown]
# From here, you could iterate on different agent logic and prompts to improve performance, or you could further decompose the evaluation into individual steps looking first at Routing, then Parameter Extraction, then Code Generation to determine where to focus.
#
# Happy building!
